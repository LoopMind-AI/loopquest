# %%
from loopquest.datasets import load_datasets
ds = load_datasets(["lnn0g3sv", "7aenvgky"])
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
for i, record in enumerate(ds):
    print(record)
    if i > 5:
        break
# Out:
# {'experiment_id': 'lnn0g3sv', 'environment_id': 'LunarLander-v2', 'episode': 0, 'step': 0, 'observation': [-0.005917453672736883, 1.4138437509536743, -0.5993836522102356, 0.12992262840270996, 0.006863578222692013, 0.13576944172382355, 0.0, 0.0], 'action': None, 'reward': 0.0, 'sub_goal': None, 'image_urls': [], 'termnated': False, 'truncated': False, 'done': False, 'info': {}, 'id': 'lnn0g3sv-LunarLander-v2-0-0', 'creation_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 285000), 'update_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 285000), 'images': []}
# {'experiment_id': 'lnn0g3sv', 'environment_id': 'LunarLander-v2', 'episode': 0, 'step': 1, 'observation': [-0.011775875464081764, 1.416200041770935, -0.5911121964454651, 0.1046953946352005, 0.012075022794306278, 0.10423877090215683, 0.0, 0.0], 'action': 3, 'reward': 0.5086495561761535, 'sub_goal': None, 'image_urls': ['http://localhost:5667/api/step/lnn0g3sv-LunarLander-v2-0-1/image/0'], 'termnated': False, 'truncated': False, 'done': False, 'info': {}, 'id': 'lnn0g3sv-LunarLander-v2-0-1', 'creation_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 297000), 'update_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 324000), 'images': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x796B008A3F10>]}
# {'experiment_id': 'lnn0g3sv', 'environment_id': 'LunarLander-v2', 'episode': 0, 'step': 2, 'observation': [-0.01763448677957058, 1.4179574251174927, -0.5911287069320679, 0.07804687321186066, 0.017283370718359947, 0.10417666286230087, 0.0, 0.0], 'action': 0, 'reward': -0.2972920248812443, 'sub_goal': None, 'image_urls': ['http://localhost:5667/api/step/lnn0g3sv-LunarLander-v2-0-2/image/0'], 'termnated': False, 'truncated': False, 'done': False, 'info': {}, 'id': 'lnn0g3sv-LunarLander-v2-0-2', 'creation_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 315000), 'update_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 354000), 'images': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x796B00891590>]}
# {'experiment_id': 'lnn0g3sv', 'environment_id': 'LunarLander-v2', 'episode': 0, 'step': 3, 'observation': [-0.023493289947509766, 1.4191148281097412, -0.5911442637443542, 0.05137372761964798, 0.022490791976451874, 0.1041579395532608, 0.0, 0.0], 'action': 0, 'reward': -0.35633582658098817, 'sub_goal': None, 'image_urls': ['http://localhost:5667/api/step/lnn0g3sv-LunarLander-v2-0-3/image/0'], 'termnated': False, 'truncated': False, 'done': False, 'info': {}, 'id': 'lnn0g3sv-LunarLander-v2-0-3', 'creation_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 340000), 'update_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 371000), 'images': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x796B17172110>]}
# {'experiment_id': 'lnn0g3sv', 'environment_id': 'LunarLander-v2', 'episode': 0, 'step': 4, 'observation': [-0.029352283105254173, 1.4196726083755493, -0.5911597013473511, 0.02470345050096512, 0.027697401121258736, 0.10414160788059235, 0.0, 0.0], 'action': 0, 'reward': -0.4176516725252384, 'sub_goal': None, 'image_urls': ['http://localhost:5667/api/step/lnn0g3sv-LunarLander-v2-0-4/image/0'], 'termnated': False, 'truncated': False, 'done': False, 'info': {}, 'id': 'lnn0g3sv-LunarLander-v2-0-4', 'creation_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 358000), 'update_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 400000), 'images': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x796B008A28D0>]}
# {'experiment_id': 'lnn0g3sv', 'environment_id': 'LunarLander-v2', 'episode': 0, 'step': 5, 'observation': [-0.03527383878827095, 1.4196395874023438, -0.5990033149719238, -0.0016163638792932034, 0.03446871042251587, 0.13543856143951416, 0.0, 0.0], 'action': 1, 'reward': -1.450290758223274, 'sub_goal': None, 'image_urls': ['http://localhost:5667/api/step/lnn0g3sv-LunarLander-v2-0-5/image/0'], 'termnated': False, 'truncated': False, 'done': False, 'info': {}, 'id': 'lnn0g3sv-LunarLander-v2-0-5', 'creation_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 387000), 'update_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 425000), 'images': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x796B0087DE90>]}
# {'experiment_id': 'lnn0g3sv', 'environment_id': 'LunarLander-v2', 'episode': 0, 'step': 6, 'observation': [-0.04128551483154297, 1.420069694519043, -0.6076881289482117, 0.018950577825307846, 0.04092593863606453, 0.12915672361850739, 0.0, 0.0], 'action': 2, 'reward': -1.9027300455241971, 'sub_goal': None, 'image_urls': ['http://localhost:5667/api/step/lnn0g3sv-LunarLander-v2-0-6/image/0'], 'termnated': False, 'truncated': False, 'done': False, 'info': {}, 'id': 'lnn0g3sv-LunarLander-v2-0-6', 'creation_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 404000), 'update_time': datetime.datetime(2024, 4, 15, 8, 10, 3, 449000), 'images': [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x796B171717D0>]}

# %%
display(record["images"][0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400>
